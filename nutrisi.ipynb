# %%
import pandas as pd

# %%
# Sample data
data = "D:\\Dataset\\nutrition.csv"
df = pd.read_csv(data)

# %%
from IPython.display import display
import pandas as pd

# Mengasumsikan df sudah didefinisikan
# Fungsi untuk memberikan warna berdasarkan indeks
def highlight_rows(row):
    return ['background-color: #f2f2f2' if row.name % 2 == 0 else 'background-color: #ffffff' for _ in row]

# Menampilkan data dalam bentuk tabel yang rapi dengan warna
styled_df = df.style.apply(highlight_rows, axis=1).set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#f7f7f9'), ('color', '#333')]}]
)

display(styled_df)
# Out:
# <style type="text/css">
# #T_99d64 thead th {
#   background-color: #f7f7f9;
#   color: #333;
# }
# ...

# %%
# Menampilkan 10 baris pertama dari dataframe
print(df.head(10))
# Out:
#             label  weight  calories  protein  carbohydrates  fats  fiber  \
# 0       apple_pie      80       240        2             36    10      2
# 1       apple_pie     100       300        3             45    12      2
# 2       apple_pie     120       360        4             54    14      3
# 3       apple_pie     150       450        5             68    18      3
# 4       apple_pie     200       600        6             90    24      4
# 5  baby_back_ribs     150       540       38             15    33      1
# 6  baby_back_ribs     200       720       50             20    44      2
# 7  baby_back_ribs     250       900       63             25    55      2
# 8  baby_back_ribs     300      1080       75             30    66      3
# 9  baby_back_ribs     350      1260       88             35    77      3
#
#    sugars  sodium
# 0      16     120
# 1      20     150
# 2      24     180
# 3      30     225
# 4      40     300
# 5      12     720
# 6      16     960
# ...

# %%
# Menampilkan 5 baris pertama dari dataframe
print(df.head())
# Out:
#        label  weight  calories  protein  carbohydrates  fats  fiber  sugars  \
# 0  apple_pie      80       240        2             36    10      2      16
# 1  apple_pie     100       300        3             45    12      2      20
# 2  apple_pie     120       360        4             54    14      3      24
# 3  apple_pie     150       450        5             68    18      3      30
# 4  apple_pie     200       600        6             90    24      4      40
#
#    sodium
# 0     120
# 1     150
# 2     180
# 3     225
# 4     300

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['weight'], df['calories'])
plt.xlabel('Weight')
plt.ylabel('Calories')
plt.title('Weight vs Calories')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Melatih model regresi linear
model.fit(X, y)

# Memprediksi nilai kalori berdasarkan berat
y_pred = model.predict(X)

# Menampilkan koefisien dan intercept dari model
print(f"Koefisien: {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")

# Menampilkan plot hasil regresi
plt.scatter(X['weight'], y, color='blue', label='Data Asli')
plt.plot(X['weight'], y_pred, color='red', label='Regresi Linear')
plt.xlabel('Weight')
plt.ylabel('Calories')
plt.title('Weight vs Calories dengan Regresi Linear')
plt.legend()
plt.show()
# Out:
# Koefisien: 1.4791190162967305
# Intercept: 145.31264172299632

# %%
# Menghitung rata-rata berat badan untuk setiap label
average_weight_per_label = df.groupby('label')['weight'].mean()

# Menampilkan label dengan rata-rata berat badan tertinggi
most_influential_label = average_weight_per_label.idxmax()
highest_average_weight = average_weight_per_label.max()

print(f"Label dengan pengaruh terbesar dalam menaikkan berat badan adalah '{most_influential_label}' dengan rata-rata berat badan {highest_average_weight:.2f}.")
# Out:
# Label dengan pengaruh terbesar dalam menaikkan berat badan adalah 'bibimbap' dengan rata-rata berat badan 500.00.

# %%
df[['weight', 'calories']].hist(bins=20, figsize=(10, 5))
plt.suptitle('Histogram of Weight and Calories')
plt.show()

# %%
df.hist(column='weight', by='label', bins=20, figsize=(20, 20), layout=(11, 10), sharex=True, sharey=True)
plt.suptitle('Histogram of Weight for Each Label')
plt.show()

# %%
# Menemukan label dengan kalori terbesar
label_max_calories = df.loc[df['calories'].idxmax(), 'label']

# Memfilter dataframe berdasarkan label tersebut
df_max_calories = df[df['label'] == label_max_calories]

# Menampilkan histogram dari semua atribut
df_max_calories.hist(bins=20, figsize=(15, 10))
plt.suptitle(f'Histogram of All Attributes for Label with Highest Calories: {label_max_calories}')
plt.show()

# %%
# Menghitung total kalori untuk setiap label
calories_per_label = df.groupby('label')['calories'].sum()

# Menampilkan pie chart
plt.figure(figsize=(10, 10))
calories_per_label.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Total Calories per Label')
plt.ylabel('')  # Menghilangkan label y
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Menggunakan kolom 'weight', 'calories', dan 'protein' untuk plot 3D
ax.scatter(df['weight'], df['calories'], df['protein'], c='r', marker='o')

ax.set_xlabel('Weight')
ax.set_ylabel('Calories')
ax.set_zlabel('Protein')

plt.title('3D Scatter Plot of Weight, Calories, and Protein')
plt.show()

# %%
import seaborn as sns

# Statistik deskriptif
print(df.describe())

# Analisis korelasi
correlation_matrix = df.drop(columns=['label']).corr()
print(correlation_matrix)

# Visualisasi korelasi menggunakan heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Visualisasi distribusi data
df.drop(columns=['label']).hist(bins=20, figsize=(15, 10))
plt.suptitle('Histogram of All Attributes')
plt.show()

# Visualisasi scatter plot untuk melihat hubungan antar variabel
sns.pairplot(df.drop(columns=['label']))
plt.suptitle('Pairplot of All Attributes')
plt.show()
# Out:
#            weight     calories     protein  carbohydrates        fats  \
# count  505.000000   505.000000  505.000000     505.000000  505.000000
# mean   227.207921   481.380198   21.215842      41.863366   23.689109
# std    102.593000   230.066679   16.294869      30.577431   14.782295
# min     50.000000    50.000000    2.000000       0.000000    1.000000
# 25%    150.000000   300.000000    9.000000      18.000000   12.000000
# 50%    200.000000   450.000000   16.000000      38.000000   20.000000
# 75%    300.000000   600.000000   30.000000      60.000000   30.000000
# max    700.000000  1260.000000   88.000000     150.000000   90.000000
#
#             fiber      sugars       sodium
# count  505.000000  505.000000   505.000000
# mean     3.310891   12.708911   595.849505
# std      2.587435   16.656319   373.087777
# min      0.000000    0.000000    10.000000
# 25%      1.000000    3.000000   300.000000
# 50%      3.000000    6.000000   600.000000
# ...

# %%
# Menghitung rata-rata berat badan untuk setiap label
average_weight_per_label = df.groupby('label')['weight'].mean()

# Menampilkan label dengan rata-rata berat badan tertinggi
most_influential_label = average_weight_per_label.idxmax()
highest_average_weight = average_weight_per_label.max()

print(f"Label dengan pengaruh terbesar dalam menaikkan berat badan adalah '{most_influential_label}' dengan rata-rata berat badan {highest_average_weight:.2f}.")
# Out:
# Label dengan pengaruh terbesar dalam menaikkan berat badan adalah 'bibimbap' dengan rata-rata berat badan 500.00.

# %%
# Memfilter dataframe berdasarkan label 'bibimbap'
df_bibimbap = df[df['label'] == 'bibimbap']

# Menampilkan histogram dari semua atribut untuk 'bibimbap'
df_bibimbap.hist(bins=20, figsize=(15, 10))
plt.suptitle('Histogram of All Attributes for Bibimbap')
plt.show()

# %%
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
import statsmodels.api as sm

# Scatter plot dari data asli dan prediksi
plt.figure(figsize=(10, 6))
plt.scatter(X['weight'], y, color='blue', label='Data Asli')
plt.plot(X['weight'], y_pred, color='red', label='Prediksi')
plt.xlabel('Weight')
plt.ylabel('Calories')
plt.title('Weight vs Calories dengan Regresi Linear')
plt.legend()
plt.show()

# Residual plot
residuals = y - y_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='purple')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('Prediksi')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# Histogram dari residuals
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='green')
plt.xlabel('Residuals')
plt.title('Histogram of Residuals')
plt.show()

# QQ plot dari residuals
plt.figure(figsize=(10, 6))
sm.qqplot(residuals, line='45')
plt.title('QQ Plot of Residuals')
plt.show()

# %%
# Menghitung rata-rata berat badan untuk setiap label
average_weight_per_label = df.groupby('label')['weight'].mean()

# Menampilkan label dengan rata-rata berat badan terendah
least_influential_label = average_weight_per_label.idxmin()
lowest_average_weight = average_weight_per_label.min()

print(f"Label dengan pengaruh paling sedikit dalam menaikkan berat badan adalah '{least_influential_label}' dengan rata-rata berat badan {lowest_average_weight:.2f}.")
# Out:
# Label dengan pengaruh paling sedikit dalam menaikkan berat badan adalah 'Cupcakes' dengan rata-rata berat badan 98.00.

# %%
import seaborn as sns

import matplotlib.pyplot as plt
import statsmodels.api as sm

# Scatter plot dari data asli dan prediksi
plt.figure(figsize=(10, 6))
plt.scatter(X['weight'], y, color='blue', label='Data Asli')
plt.plot(X['weight'], y_pred, color='red', label='Prediksi')
plt.xlabel('Weight')
plt.ylabel('Calories')
plt.title('Weight vs Calories dengan Regresi Linear')
plt.legend()
plt.show()

# Residual plot
residuals = y - y_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='purple')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('Prediksi')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# Histogram dari residuals
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='green')
plt.xlabel('Residuals')
plt.title('Histogram of Residuals')
plt.show()

# QQ plot dari residuals
plt.figure(figsize=(10, 6))
sm.qqplot(residuals, line='45')
plt.title('QQ Plot of Residuals')
plt.show()
